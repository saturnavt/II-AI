# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Load csv
data = pd.read_csv('resources/DATOS_DE_CALIDAD_DEL_AIRE_EN_COLOMBIA_2011-2018 - DATOS_DE_CALIDAD_DEL_AIRE_EN_COLOMBIA_2011-2018.csv')
# Out:
# C:\Users\illud\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
envigado = data[data.Nombre_del_municipio == 'ENVIGADO']
data.sample(30)
# Out:
#                             Fecha Autoridad Ambiental  Nombre de la estación  \
# 44330   26/08/2012 02:00:00 a. m.        CORANTIOQUIA    Envigado-Fundadores
# 111519  24/07/2013 04:00:00 a. m.        CORANTIOQUIA    Envigado-Fundadores
# 182229            16/05/2018 0:00        CORANTIOQUIA  Ca. Envigado EIA 2017
# 188989            30/09/2018 2:00        CORANTIOQUIA           Envigado-IUE
# 70127   04/01/2012 12:00:00 p. m.        CORANTIOQUIA    Envigado-Fundadores
# 25784   12/10/2012 02:00:00 p. m.        CORANTIOQUIA    Envigado-Fundadores
# 85456   24/08/2011 10:00:00 a. m.        CORANTIOQUIA    Envigado-Fundadores
# 140169  23/01/2016 01:00:00 a. m.        CORANTIOQUIA           Envigado-IUE
# 93376   12/10/2012 01:00:00 a. m.        CORANTIOQUIA    Envigado-Fundadores
# 157829           25/05/2018 19:00        CORANTIOQUIA  Ca. Envigado EIA 2017
# 140727  24/02/2016 07:00:00 a. m.        CORANTIOQUIA           Envigado-IUE
# ...

# %%
plt.bar(envigado.Fecha.sample(2), envigado.Concentracion.sample(2))
# Out:
# <BarContainer object of 2 artists>
